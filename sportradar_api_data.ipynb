# %%
import requests
import pandas as pd
import http.client
import ast

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", "/ufc/trial/v2/en/competitions.json?api_key=x9gezn9xpjjetay87mxhqxr9")

res = conn.getresponse()
data = res.read()

competitions = data.decode("utf-8")

print(competitions)

# %%
type(competitions)

# %%
comps = ast.literal_eval(competitions)

# %%
type(comps)

# %%
lstofcomps = comps['competitions']

# %%
type(lstofcomps)

# %%
len(lstofcomps)

# %%
#why are there only 96 ufc events in this data??
#does this give me everything?

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", "/ufc/trial/v2/en/competitors/sr:competitor:237660/summaries.json?api_key=x9gezn9xpjjetay87mxhqxr9")

res = conn.getresponse()
data = res.read()

Ry_L = data.decode("utf-8")

print(Ry_L)
# Out:
# {
#     "generated_at": "2019-10-10T14:49:38+00:00",
#     "summaries": [
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:15412956",
#                 "start_time": "2018-10-06T22:30:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:117",
#                         "name": "MMA"
#                     },
#                     "category": {
#                         "id": "sr:category:1089",
#                         "name": "UFC"
#                     },
#                     "competition": {
#                         "id": "sr:competition:25791",
#                         "name": "UFC 229 - Las Vegas",
#                         "parent_id": "sr:competition:25325"
#                     },
#                     "season": {
#                         "id": "sr:season:55905",
# ...

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")

conn.request("GET", "http://api.sportradar.us/ufc/trial/v2/en/schedules/2019-10-05/summaries.json?api_key=x9gezn9xpjjetay87mxhqxr9")

res = conn.getresponse()
data = res.read()

OCT_5_19 = data.decode("utf-8")
print(OCT_5_19)
# Out:
# {
#     "generated_at": "2019-10-10T15:14:19+00:00",
#     "summaries": [
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:19638860",
#                 "start_time": "2019-10-05T22:45:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:117",
#                         "name": "MMA"
#                     },
#                     "category": {
#                         "id": "sr:category:1089",
#                         "name": "UFC"
#                     },
#                     "competition": {
#                         "id": "sr:competition:29910",
#                         "name": "Ufc 243 - Melbourne",
#                         "parent_id": "sr:competition:25325"
#                     },
#                     "season": {
#                         "id": "sr:season:70214",
# ...
