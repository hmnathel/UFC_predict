# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
results = requests.get("http://ufcstats.com/statistics/events/completed?page=all")

# %%
print(results.status_code)
# Out:
# 200

# %%
src = results.content

# %%
src
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js ie8 lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <title>\n    Stats | UFC\n  </title>\n  <meta name="description" content="">\n  <meta name="viewport" content="">\n  <link rel="stylesheet" href="/blocks/main.css?ver=801037">\n  <script src="/js/vendor/modernizr-2.6.2.min.js"></script>\n  <script>\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n    ga(\'cr
# ...

# %%
events = soup.find_all("a", {"class": "b-link_style_black"})

# %%
events
# Out:
# [<a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/3cf68c1d17f66af7">
#                            UFC 243: Whittaker vs. Adesanya
#                          </a>,
#  <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/1bf49bf829964144">
#                            UFC Fight Night: Hermansson vs. Cannonier
#                          </a>,
#  <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/94a5aaf573f780ad">
#                            UFC Fight Night: Rodriguez vs. Stephens
#                          </a>,
#  <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/4834ff149dc9542a">
#                            UFC Fight Night: Cowboy vs. Gaethje
#                          </a>,
#  <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/a79bfbc01b2264d6">
#                            UFC 242: Khabib vs. Poirier
#                          </a>,
# ...

# %%
eventlinks = []
for a in soup.find_all("a", {"class": "b-link_style_black"}):
    eventlinks.append(a['href'])

# %%
len(eventlinks)
# Out:
# 496

# %%
events06on = eventlinks[0:431]

# %%
events06on
# Out:
# ['http://ufcstats.com/event-details/3cf68c1d17f66af7',
#  'http://ufcstats.com/event-details/1bf49bf829964144',
#  'http://ufcstats.com/event-details/94a5aaf573f780ad',
#  'http://ufcstats.com/event-details/4834ff149dc9542a',
#  'http://ufcstats.com/event-details/a79bfbc01b2264d6',
#  'http://ufcstats.com/event-details/2c104b7e59a72629',
#  'http://ufcstats.com/event-details/70167689d6a01793',
#  'http://ufcstats.com/event-details/e5d03e4d966126bd',
#  'http://ufcstats.com/event-details/03da33a102d9a45f',
#  'http://ufcstats.com/event-details/abcf7e55a0a9ed89',
#  'http://ufcstats.com/event-details/9e0f28d1f639ad73',
#  'http://ufcstats.com/event-details/2f8f3c69522db931',
#  'http://ufcstats.com/event-details/6c9383ffab2725a5',
#  'http://ufcstats.com/event-details/c0c1bc0766df4c00',
#  'http://ufcstats.com/event-details/b16a7e6a627e9789',
#  'http://ufcstats.com/event-details/e31502e3f79d00c5',
#  'http://ufcstats.com/event-details/cbc071cb20ea59c7',
# ...

# %%
comps = []
fights = []
for event in events06on:
    comps.append(requests.get(event))
    for comp in comps:
        fights.append(comp.content)
        for fight in fights:

# %%
fights
